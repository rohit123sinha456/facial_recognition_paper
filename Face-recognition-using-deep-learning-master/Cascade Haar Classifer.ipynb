# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)

# %%
cap,frame = vid.read()
plt.imshow(frame)
plt.show()

# %%
cv2.imwrite('images/RohitOriginal.jpg',frame)
# Out:
# True

# %%
face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
img = cv2.imread('images/RohitOriginal.jpg')
vid.release()

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap='gray')
plt.show()

# %%
faces = face.detectMultiScale(img_gray,1.3,20)

# %%
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),10)
    roi_gray = img_gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

plt.imshow(img)
plt.show()

# %%
faces
# Out:
# array([[431,  57, 374, 374]], dtype=int32)
